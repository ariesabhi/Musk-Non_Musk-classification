# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('../input/musk-dataset/musk_csv.csv')
data.head()
# Out:
#    ID molecule_name conformation_name  f1   f2   f3  f4   f5  f6  f7  ...  \
# 0   1      MUSK-211           211_1+1  46 -108  -60 -69 -117  49  38  ...
# 1   2      MUSK-211          211_1+10  41 -188 -145  22 -117  -6  57  ...
# 2   3      MUSK-211          211_1+11  46 -194 -145  28 -117  73  57  ...
# 3   4      MUSK-211          211_1+12  41 -188 -145  22 -117  -7  57  ...
# 4   5      MUSK-211          211_1+13  41 -188 -145  22 -117  -7  57  ...
#
#    f158  f159  f160  f161  f162  f163  f164  f165  f166  class
# 0  -308    52    -7    39   126   156   -50  -112    96      1
# 1   -59    -2    52   103   136   169   -61  -136    79      1
# 2  -134  -154    57   143   142   165   -67  -145    39      1
# 3   -60    -4    52   104   136   168   -60  -135    80      1
# 4   -60    -4    52   104   137   168   -60  -135    80      1
#
# [5 rows x 170 columns]

# %%
data.count()
# Out:
# ID                   6598
# molecule_name        6598
# conformation_name    6598
# f1                   6598
# f2                   6598
#                      ...
# f163                 6598
# f164                 6598
# f165                 6598
# f166                 6598
# class                6598
# Length: 170, dtype: int64

# %%
data.describe()
# Out:
#                ID           f1           f2           f3           f4  \
# count  6598.00000  6598.000000  6598.000000  6598.000000  6598.000000
# mean   3299.50000    58.945135  -119.128524   -73.146560    -0.628372
# std    1904.82287    53.249007    90.813375    67.956235    80.444617
# min       1.00000   -31.000000  -199.000000  -167.000000  -114.000000
# 25%    1650.25000    37.000000  -193.000000  -137.000000   -70.000000
# 50%    3299.50000    44.000000  -149.000000   -99.000000   -25.000000
# 75%    4948.75000    53.000000   -95.000000   -19.000000    42.000000
# max    6598.00000   292.000000    95.000000    81.000000   161.000000
#
#                 f5           f6           f7           f8           f9  ...  \
# count  6598.000000  6598.000000  6598.000000  6598.000000  6598.000000  ...
# mean   -103.533495    18.359806   -14.108821    -1.858290   -86.003031  ...
# std      64.387559    80.593655   115.315673    90.372537   108.326676  ...
# min    -118.000000  -183.000000  -171.000000  -225.000000  -245.000000  ...
# 25%    -117.000000   -28.000000  -159.000000   -85.000000  -217.000000  ...
# 50%    -117.000000    33.000000    27.000000    19.000000   -40.000000  ...
# 75%    -116.000000    74.000000    57.000000    61.000000   -21.000000  ...
# max     325.000000   200.000000   220.000000   320.000000   147.000000  ...
#
#               f158         f159         f160         f161         f162  \
# count  6598.000000  6598.000000  6598.000000  6598.000000  6598.000000
# mean   -184.798272   -75.795696   -26.073204    64.616702   112.037739
# std     107.819514   127.861271    69.727964   100.861935    72.835040
# min    -328.000000  -219.000000  -136.000000  -120.000000   -69.000000
# 25%    -272.000000  -205.000000   -70.000000   -18.000000    71.000000
# 50%    -234.000000  -131.000000   -21.000000    61.500000   107.000000
# 75%     -80.000000    52.000000     9.000000   149.000000   129.000000
# max      94.000000   179.000000   192.000000   411.000000   355.000000
#
#               f163         f164         f165         f166        class
# count  6598.000000  6598.000000  6598.000000  6598.000000  6598.000000
# mean    201.760230   -47.488330  -150.259927    41.770233     0.154138
# std      59.526751    55.069365    76.019023    94.116085     0.361108
# min      73.000000  -289.000000  -428.000000  -471.000000     0.000000
# 25%     166.000000   -68.000000  -179.000000    -9.000000     0.000000
# 50%     191.000000   -60.000000  -150.000000    27.000000     0.000000
# 75%     215.000000   -45.000000  -120.000000   119.000000     0.000000
# max     625.000000   295.000000   168.000000   367.000000     1.000000
#
# [8 rows x 168 columns]

# %%
data.nunique()
# Out:
# ID                   6598
# molecule_name         102
# conformation_name    6598
# f1                    202
# f2                    260
#                      ...
# f163                  292
# f164                  172
# f165                  352
# f166                  385
# class                   2
# Length: 170, dtype: int64

# %% [markdown]
# #since id and confronation names are unique ,we can remove them.

# %%
new_data=data.copy()

# %%
new_data.head()
# Out:
#    ID molecule_name conformation_name  f1   f2   f3  f4   f5  f6  f7  ...  \
# 0   1      MUSK-211           211_1+1  46 -108  -60 -69 -117  49  38  ...
# 1   2      MUSK-211          211_1+10  41 -188 -145  22 -117  -6  57  ...
# 2   3      MUSK-211          211_1+11  46 -194 -145  28 -117  73  57  ...
# 3   4      MUSK-211          211_1+12  41 -188 -145  22 -117  -7  57  ...
# 4   5      MUSK-211          211_1+13  41 -188 -145  22 -117  -7  57  ...
#
#    f158  f159  f160  f161  f162  f163  f164  f165  f166  class
# 0  -308    52    -7    39   126   156   -50  -112    96      1
# 1   -59    -2    52   103   136   169   -61  -136    79      1
# 2  -134  -154    57   143   142   165   -67  -145    39      1
# 3   -60    -4    52   104   136   168   -60  -135    80      1
# 4   -60    -4    52   104   137   168   -60  -135    80      1
#
# [5 rows x 170 columns]

# %%
new_data.drop(['molecule_name','ID','conformation_name'],axis=1,inplace=True)

# %%
new_data.head()
# Out:
#    f1   f2   f3  f4   f5  f6  f7   f8  f9  f10  ...  f158  f159  f160  f161  \
# 0  46 -108  -60 -69 -117  49  38 -161  -8    5  ...  -308    52    -7    39
# 1  41 -188 -145  22 -117  -6  57 -171 -39 -100  ...   -59    -2    52   103
# 2  46 -194 -145  28 -117  73  57 -168 -39  -22  ...  -134  -154    57   143
# 3  41 -188 -145  22 -117  -7  57 -170 -39  -99  ...   -60    -4    52   104
# 4  41 -188 -145  22 -117  -7  57 -170 -39  -99  ...   -60    -4    52   104
#
#    f162  f163  f164  f165  f166  class
# 0   126   156   -50  -112    96      1
# 1   136   169   -61  -136    79      1
# 2   142   165   -67  -145    39      1
# 3   136   168   -60  -135    80      1
# 4   137   168   -60  -135    80      1
#
# [5 rows x 167 columns]

# %%
new_data.isnull().values.any()
# Out:
# False

# %% [markdown]
# #There are no null values present in the dataset

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(new_data, new_data['class'], test_size = 0.20,random_state=120)

# %%
import keras
from keras.models import Model
from keras.layers import *

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (5278, 167)
# (1320, 167)

# %%
Inp=Input(shape=(167,))
x=Dense(500,activation='sigmoid',name='Hidden_layer1')(Inp)
x=Dense(300,activation='relu',name='Hidden_layer2')(x)
x=Dense(155,activation='sigmoid',name='Hidden_layer3')(x)
x=Dense(80,activation='relu',name='Hidden_layer4')(x)
output=Dense(1,activation='sigmoid',name='Output_layer')(x)

# %%
model=Model(Inp,output)
model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 167)               0
# _________________________________________________________________
# Hidden_layer1 (Dense)        (None, 500)               84000
# _________________________________________________________________
# Hidden_layer2 (Dense)        (None, 300)               150300
# _________________________________________________________________
# Hidden_layer3 (Dense)        (None, 155)               46655
# _________________________________________________________________
# Hidden_layer4 (Dense)        (None, 80)                12480
# _________________________________________________________________
# Output_layer (Dense)         (None, 1)                 81
# =================================================================
# Total params: 293,516
# Trainable params: 293,516
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import optimizers

# %%
l_rate=0.00001
training_epoch=50
batch_size=700
adma=optimizers.adam(lr=l_rate)

# %%
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
op=model.fit(X_train,Y_train,batch_size=batch_size,epochs=training_epoch,verbose=2,validation_data=(X_test,Y_test))
# Out:
# Train on 5278 samples, validate on 1320 samples
# Epoch 1/50
#  - 0s - loss: 0.4647 - accuracy: 0.8128 - val_loss: 0.3950 - val_accuracy: 0.8485
# Epoch 2/50
#  - 0s - loss: 0.3838 - accuracy: 0.8452 - val_loss: 0.3508 - val_accuracy: 0.8485
# Epoch 3/50
#  - 0s - loss: 0.3212 - accuracy: 0.8636 - val_loss: 0.2772 - val_accuracy: 0.8977
# Epoch 4/50
#  - 0s - loss: 0.2361 - accuracy: 0.9132 - val_loss: 0.1983 - val_accuracy: 0.9371
# Epoch 5/50
#  - 0s - loss: 0.1630 - accuracy: 0.9481 - val_loss: 0.1639 - val_accuracy: 0.9364
# Epoch 6/50
#  - 0s - loss: 0.1215 - accuracy: 0.9568 - val_loss: 0.1258 - val_accuracy: 0.9538
# Epoch 7/50
#  - 0s - loss: 0.0980 - accuracy: 0.9653 - val_loss: 0.1122 - val_accuracy: 0.9523
# Epoch 8/50
#  - 0s - loss: 0.0849 - accuracy: 0.9693 - val_loss: 0.0943 - val_accuracy: 0.9644
# Epoch 9/50
#  - 0s - loss: 0.0768 - accuracy: 0.9737 - val_loss: 0.0953 - val_accuracy: 0.9606
# Epoch 10/50
#  - 0s - loss: 0.0720 - accuracy: 0.9729 - val_loss: 0.0850 - val_accuracy: 0.9652
# Epoch 11/50
#  - 0s - loss: 0.0618 - accuracy: 0.9784 - val_loss: 0.0839 - val_accuracy: 0.9667
# Epoch 12/50
#  - 0s - loss: 0.0579 - accuracy: 0.9782 - val_loss: 0.0966 - val_accuracy: 0.9644
# Epoch 13/50
#  - 0s - loss: 0.0571 - accuracy: 0.9795 - val_loss: 0.0879 - val_accuracy: 0.9614
# Epoch 14/50
#  - 0s - loss: 0.0550 - accuracy: 0.9782 - val_loss: 0.0692 - val_accuracy: 0.9742
# Epoch 15/50
#  - 0s - loss: 0.0472 - accuracy: 0.9820 - val_loss: 0.0932 - val_accuracy: 0.9674
# Epoch 16/50
#  - 0s - loss: 0.0535 - accuracy: 0.9805 - val_loss: 0.0902 - val_accuracy: 0.9697
# Epoch 17/50
#  - 0s - loss: 0.0488 - accuracy: 0.9818 - val_loss: 0.0821 - val_accuracy: 0.9697
# Epoch 18/50
#  - 0s - loss: 0.0447 - accuracy: 0.9828 - val_loss: 0.0709 - val_accuracy: 0.9727
# Epoch 19/50
#  - 0s - loss: 0.0420 - accuracy: 0.9835 - val_loss: 0.0996 - val_accuracy: 0.9583
# Epoch 20/50
#  - 0s - loss: 0.0670 - accuracy: 0.9742 - val_loss: 0.1321 - val_accuracy: 0.9568
# Epoch 21/50
#  - 0s - loss: 0.0599 - accuracy: 0.9773 - val_loss: 0.0749 - val_accuracy: 0.9667
# Epoch 22/50
#  - 0s - loss: 0.0566 - accuracy: 0.9771 - val_loss: 0.1038 - val_accuracy: 0.9598
# Epoch 23/50
#  - 0s - loss: 0.0659 - accuracy: 0.9733 - val_loss: 0.0606 - val_accuracy: 0.9735
# Epoch 24/50
#  - 0s - loss: 0.0551 - accuracy: 0.9786 - val_loss: 0.0816 - val_accuracy: 0.9667
# Epoch 25/50
#  - 0s - loss: 0.0436 - accuracy: 0.9828 - val_loss: 0.0743 - val_accuracy: 0.9682
# Epoch 26/50
#  - 0s - loss: 0.0455 - accuracy: 0.9818 - val_loss: 0.0760 - val_accuracy: 0.9727
# Epoch 27/50
#  - 0s - loss: 0.0483 - accuracy: 0.9818 - val_loss: 0.0784 - val_accuracy: 0.9689
# Epoch 28/50
#  - 0s - loss: 0.0447 - accuracy: 0.9841 - val_loss: 0.0661 - val_accuracy: 0.9742
# Epoch 29/50
#  - 0s - loss: 0.0427 - accuracy: 0.9839 - val_loss: 0.0685 - val_accuracy: 0.9712
# Epoch 30/50
#  - 0s - loss: 0.0393 - accuracy: 0.9860 - val_loss: 0.0715 - val_accuracy: 0.9705
# Epoch 31/50
#  - 0s - loss: 0.0322 - accuracy: 0.9877 - val_loss: 0.0879 - val_accuracy: 0.9667
# Epoch 32/50
#  - 0s - loss: 0.0406 - accuracy: 0.9833 - val_loss: 0.0682 - val_accuracy: 0.9705
# Epoch 33/50
#  - 0s - loss: 0.0504 - accuracy: 0.9792 - val_loss: 0.0755 - val_accuracy: 0.9689
# Epoch 34/50
#  - 0s - loss: 0.0502 - accuracy: 0.9803 - val_loss: 0.0992 - val_accuracy: 0.9682
# Epoch 35/50
#  - 0s - loss: 0.0436 - accuracy: 0.9839 - val_loss: 0.0754 - val_accuracy: 0.9667
# Epoch 36/50
#  - 0s - loss: 0.0406 - accuracy: 0.9824 - val_loss: 0.0939 - val_accuracy: 0.9667
# Epoch 37/50
#  - 0s - loss: 0.0449 - accuracy: 0.9843 - val_loss: 0.0822 - val_accuracy: 0.9697
# Epoch 38/50
#  - 0s - loss: 0.0382 - accuracy: 0.9854 - val_loss: 0.0720 - val_accuracy: 0.9735
# Epoch 39/50
#  - 0s - loss: 0.0337 - accuracy: 0.9890 - val_loss: 0.0704 - val_accuracy: 0.9682
# Epoch 40/50
#  - 0s - loss: 0.0495 - accuracy: 0.9816 - val_loss: 0.0800 - val_accuracy: 0.9682
# Epoch 41/50
#  - 0s - loss: 0.0385 - accuracy: 0.9848 - val_loss: 0.0646 - val_accuracy: 0.9720
# Epoch 42/50
#  - 0s - loss: 0.0412 - accuracy: 0.9833 - val_loss: 0.0727 - val_accuracy: 0.9705
# Epoch 43/50
#  - 0s - loss: 0.0492 - accuracy: 0.9809 - val_loss: 0.0794 - val_accuracy: 0.9720
# Epoch 44/50
#  - 0s - loss: 0.0480 - accuracy: 0.9811 - val_loss: 0.0968 - val_accuracy: 0.9621
# Epoch 45/50
#  - 0s - loss: 0.0573 - accuracy: 0.9765 - val_loss: 0.1016 - val_accuracy: 0.9606
# Epoch 46/50
#  - 0s - loss: 0.0570 - accuracy: 0.9775 - val_loss: 0.1077 - val_accuracy: 0.9636
# Epoch 47/50
#  - 0s - loss: 0.0703 - accuracy: 0.9725 - val_loss: 0.1012 - val_accuracy: 0.9644
# Epoch 48/50
#  - 0s - loss: 0.0620 - accuracy: 0.9754 - val_loss: 0.0912 - val_accuracy: 0.9644
# Epoch 49/50
#  - 0s - loss: 0.0552 - accuracy: 0.9788 - val_loss: 0.0702 - val_accuracy: 0.9689
# Epoch 50/50
#  - 0s - loss: 0.0473 - accuracy: 0.9816 - val_loss: 0.0888 - val_accuracy: 0.9705

# %%
print(op.history.keys())
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy'])

# %%
plt.plot(op.history['loss'],label='train')
plt.xlabel('epochs')
plt.plot(op.history['val_loss'],label='test')
plt.ylabel('loss')
plt.legend()
plt.show()

# %%
plt.plot(op.history['accuracy'],label='train')
plt.xlabel('epochs')
plt.plot(op.history['val_accuracy'],label='test')
plt.ylabel('accuracy')
plt.legend()
plt.show()

# %%
Y_pred=model.predict(X_test).astype('int').flatten()
print(Y_pred)
# Out:
# [[0]
#  [0]
#  [0]
#  ...
#  [0]
#  [0]
#  [0]]

# %%
from sklearn.metrics import classification_report
cls = classification_report(Y_test,Y_pred)
print(cls)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      1.00      0.92      1120
#            1       0.00      0.00      0.00       200
#
#     accuracy                           0.85      1320
#    macro avg       0.42      0.50      0.46      1320
# weighted avg       0.72      0.85      0.78      1320
# /opt/conda/lib/python3.6/site-packages/sklearn/metrics/classification.py:1437: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
